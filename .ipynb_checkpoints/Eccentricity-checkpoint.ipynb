# %%
from matplotlib import pyplot as plt
import numpy as np
import os
import cv2

# %%
pwd
# Out:
# 'C:\\Users\\sinad\\Dropbox (Gladstone)\\Feature_based_classification'

# %%
input_path = 'C:\\Users\\sinad\\Dropbox (Gladstone)\\Feature_based_classification\\FIJI_SingleTp_S_CTR_1'
img_list = os.listdir(input_path)
current_img_path = os.path.join(input_path, img_list[6])
current_img = cv2.imread(current_img_path)
plt.imshow(current_img)

# %%
edges = cv2.Canny(current_img, 150, 300)
plt.imshow(edges, cmap='gray')

# %%
imgray = cv2.cvtColor(current_img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 150, 255, cv2.THRESH_BINARY)
adaptive_thresh = cv2.adaptiveThreshold(imgray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)
plt.imshow(thresh)

# %%
countours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
plt.imshow(cv2.drawContours(current_img, countours, -1, (0,0,255), 1))

# %%
from imutils import contours
# countours_sorted = contours.sort_contours(countours)[0]
contours_sorted = sorted(countours, key=lambda ctr: cv2.boundingRect(ctr)[1])
# print("sorted Countours are: ", countours)
contour_length = []
for c in countours:
    contour_length.append(len(c))

print("the length of contours are: ", contour_length)
contour_max_idx = contour_length.index(max(contour_length))
print("the index of the max contour is: ", contour_max_idx)
cnt = countours[contour_max_idx]
moment = cv2.moments(cnt)
# print("the moments are: ", moment['m10'])
m_cx = int(moment['m10']/moment['m00'])
m_cy = int(moment['m01']/moment['m00'])

m_centroid = (m_cx, m_cy)
# # (150, 160)
print("centroid is x and y is: ", m_centroid)
# Out:
# the length of contours are:  [1, 2, 1, 1, 1, 149, 4, 4, 4, 4, 6, 4, 4, 4, 4, 4, 4, 4, 4, 1]
# the index of the max contour is:  5
# centroid is x and y is:  (152, 150)

# %%
threshold_ellipse = cv2.fitEllipse(cnt)
print("the ellipse is: ", threshold_ellipse)
# ellipse = (centroid, (50, 30), 128)
threshold_ellipse_img = cv2.ellipse(current_img, threshold_ellipse, (255,0,0), 2)
plt.imshow(threshold_ellipse_img)
# Out:
# the ellipse is:  ((151.2689208984375, 150.95559692382812), (23.94481658935547, 59.257057189941406), 39.799686431884766)

# %%
countours_canny, hierarchy_canny = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
canny_contour_length = []
for c in countours_canny:
    canny_contour_length.append(len(c))

print("the length of contours are: ", canny_contour_length)
canny_contour_max_idx = canny_contour_length.index(max(canny_contour_length))
print("the index of the max canny contour is: ", canny_contour_max_idx)
cnt_canny = countours_canny[canny_contour_max_idx]
# plt.imshow(cv2.drawContours(current_img, countours_canny, -1, (0,255,0), 2))
M = cv2.moments(cnt_canny)
# print(cnt_canny)
# print(M)
# print("hierarchy is: ", hierarchy_canny)
# Out:
# the length of contours are:  [4, 6, 2, 3, 2, 14, 8, 2, 2, 139, 6, 4, 4, 6, 10, 4, 5, 7, 16, 40, 2, 2, 179, 6, 49]
# the index of the max canny contour is:  22

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])

centroid = (cx, cy)
# (150, 160)
print("centroid is x and y is: ", centroid)
# print("countours_canny is: ", countours_canny[0])
# Out:
# centroid is x and y is:  (147, 143)

# %%
radius = int(25)
# circle_img = cv2.circle(current_img, centroid, radius, (0,255, 255), 2)
# plt.imshow(circle_img)

# %%
ellipse = cv2.fitEllipse(cnt_canny)
print("the ellipse is: ", ellipse)
ellipse = (centroid, (50, 30), 128)
ellipse_img = cv2.ellipse(current_img, ellipse, (0,255,255), 2)
plt.imshow(ellipse_img)
# Out:
# the ellipse is:  ((145.37753295898438, 145.76368713378906), (23.374740600585938, 65.81948852539062), 55.73971176147461)

# %%
# Eccentricity calculation: sqrt(1- (minorAxix/majorAxis)^2)
(center, axis, orientatino) = threshold_ellipse

#Length of the major and minor axis
majorAxis = max(axis)
minorAxis = min(axis)

print("the major and minor axis are: ", majorAxis, minorAxis)
eccentricity = np.sqrt(1-(minorAxis/majorAxis)**2)
print("the eccentricity is: ", eccentricity)
# Out:
# the major and minor axis are:  35.26530075073242 30.28948211669922
# the eccentricity is:  0.5121378462338673

# %%
img_eccentricity_list = []
for img in img_list:
    current_img_path = os.path.join(input_path, img)
    current_img = cv2.imread(current_img_path)
    current_img_normalized = (current_img - current_img.min()) / (current_img.max() - current_img.min())
#     plt.hist(current_img_normalized.ravel(), bins=256)
    current_img_normalized_mean = current_img_normalized.mean()
    current_img_normalized_std = current_img_normalized.std()
    mean_correction_factor = 0.25 - current_img_normalized_mean
    stdDev_correction_factor = 0.125 / current_img_normalized_std
    current_img_standardized = (current_img_normalized - mean_correction_factor) * stdDev_correction_factor
    current_img_standardized_corrected = current_img_standardized + (0.25 - current_img_standardized.mean())
    current_img_standardized_clipped = current_img_standardized_corrected.clip(0.02, 0.9)
    current_img_standardized_clipped_rescaled = np.array(current_img_standardized_clipped * pow(2,8), dtype=np.uint8)
    imgray = cv2.cvtColor(current_img_standardized_clipped_rescaled, cv2.COLOR_BGR2GRAY)
    
    ret, thresh = cv2.threshold(imgray, 150, 255, 0)
    plt.imshow(current_img_standardized_clipped_rescaled)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contour_length = []
    for c in contours:
        contour_length.append(len(c))

#     print("the length of contours are: ", contour_length)
    contour_max_idx = contour_length.index(max(contour_length))
    print("the index of the max contour is: ", contour_max_idx)
    cnt = contours[contour_max_idx]
#     print("the contours points are: ", contours)
    threshold_ellipse = cv2.fitEllipse(cnt)
    (center, axis, orientation) = threshold_ellipse
    major_axis = max(axis)
    minor_axis = min(axis)
    # print("the major and minor axis are: ", major_axis, minor_axis)
    eccentricity = np.sqrt(1-(minor_axis/major_axis)**2)
    current_img_eccentricity = np.round(eccentricity, 2)
    img_eccentricity_list.append([img, current_img_eccentricity])

print(img_eccentricity_list)
# Out:
# the index of the max contour is:  2
# the index of the max contour is:  1
# the index of the max contour is:  25
# the index of the max contour is:  11
# the index of the max contour is:  4
# the index of the max contour is:  72
# the index of the max contour is:  87
# the index of the max contour is:  15
# the index of the max contour is:  3
# the index of the max contour is:  0
# the index of the max contour is:  8
# the index of the max contour is:  5
# the index of the max contour is:  15
# the index of the max contour is:  2
# the index of the max contour is:  3
# the index of the max contour is:  8
# the index of the max contour is:  4
# the index of the max contour is:  37
# the index of the max contour is:  29
# the index of the max contour is:  13
# the index of the max contour is:  21
# the index of the max contour is:  215
# the index of the max contour is:  32
# the index of the max contour is:  41
# the index of the max contour is:  86
# the index of the max contour is:  14
# the index of the max contour is:  28
# the index of the max contour is:  21
# the index of the max contour is:  8
# the index of the max contour is:  28
# the index of the max contour is:  603
# the index of the max contour is:  30
# the index of the max contour is:  0
# the index of the max contour is:  14
# the index of the max contour is:  1
# the index of the max contour is:  3
# the index of the max contour is:  44
# the index of the max contour is:  14
# the index of the max contour is:  10
# the index of the max contour is:  478
# the index of the max contour is:  186
# the index of the max contour is:  24
# the index of the max contour is:  556
# the index of the max contour is:  159
# the index of the max contour is:  44
# the index of the max contour is:  9
# the index of the max contour is:  33
# the index of the max contour is:  109
# the index of the max contour is:  38
# the index of the max contour is:  42
# the index of the max contour is:  7
# the index of the max contour is:  44
# the index of the max contour is:  126
# the index of the max contour is:  67
# the index of the max contour is:  241
# the index of the max contour is:  68
# the index of the max contour is:  955
# the index of the max contour is:  64
# the index of the max contour is:  39
# the index of the max contour is:  200
# the index of the max contour is:  86
# the index of the max contour is:  12
# the index of the max contour is:  27
# the index of the max contour is:  277
# the index of the max contour is:  0
# the index of the max contour is:  194
# the index of the max contour is:  13
# the index of the max contour is:  94
# the index of the max contour is:  1191
# the index of the max contour is:  11
# the index of the max contour is:  170
# the index of the max contour is:  7
# the index of the max contour is:  159
# the index of the max contour is:  6
# the index of the max contour is:  30
# the index of the max contour is:  115
# the index of the max contour is:  488
# the index of the max contour is:  1683
# the index of the max contour is:  1212
# the index of the max contour is:  268
# the index of the max contour is:  207
# the index of the max contour is:  7
# the index of the max contour is:  8
# the index of the max contour is:  19
# the index of the max contour is:  10
# the index of the max contour is:  8
# the index of the max contour is:  3
# the index of the max contour is:  103
# the index of the max contour is:  89
# the index of the max contour is:  232
# the index of the max contour is:  8
# the index of the max contour is:  3
# the index of the max contour is:  19
# the index of the max contour is:  8
# the index of the max contour is:  347
# the index of the max contour is:  1
# the index of the max contour is:  0
# the index of the max contour is:  2
# the index of the max contour is:  79
# the index of the max contour is:  23
# the index of the max contour is:  14
# the index of the max contour is:  34
# the index of the max contour is:  28
# the index of the max contour is:  41
# the index of the max contour is:  22
# [['PID20190102_SB11-15-Plate1_T0_0_A10_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_9.tif', 0.66], ['PID20190102_SB11-15-Plate1_T0_0_B10_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_4.tif', 0.72], ['PID20190102_SB11-15-Plate1_T0_0_B11_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_11.tif', 0.54], ['PID20190102_SB11-15-Plate1_T0_0_C6_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_6.tif', 0.6], ['PID20190102_SB11-15-Plate1_T0_0_D7_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_2.tif', 0.71], ['PID20190102_SB11-15-Plate1_T0_0_D9_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_13.tif', 0.84], ['PID20190102_SB11-15-Plate1_T0_0_D9_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_8.tif', 0.93], ['PID20190102_SB11-15-Plate1_T0_0_E10_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_4.tif', 0.75], ['PID20190102_SB11-15-Plate1_T0_0_E8_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_11.tif', 0.79], ['PID20190102_SB11-15-Plate1_T0_0_G10_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_4.tif', 0.88], ['PID20190102_SB11-15-Plate2_T0_0_A8_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_10.tif', 0.7], ['PID20190102_SB11-15-Plate2_T0_0_A9_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_10.tif', 0.74], ['PID20190102_SB11-15-Plate2_T0_0_C10_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_2.tif', 0.79], ['PID20190102_SB11-15-Plate2_T0_0_C11_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_7.tif', 0.81], ['PID20190102_SB11-15-Plate2_T0_0_C12_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_8.tif', 0.79], ['PID20190102_SB11-15-Plate2_T0_0_C8_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_6.tif', 0.86], ['PID20190102_SB11-15-Plate2_T0_0_G8_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_6.tif', 0.7], ['PID20190102_SB11-15-Plate2_T0_0_H11_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_16.tif', 0.62], ['PID20190102_SB11-15-Plate2_T0_0_H12_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_11.tif', 0.59], ['PID20190102_SB11-15-Plate2_T0_0_H12_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_12.tif', 0.74], ['PID20190102_SB11-15-Plate3_T0_0_A1_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_3.tif', 0.93], ['PID20190102_SB11-15-Plate3_T0_0_A2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_9.tif', 0.78], ['PID20190102_SB11-15-Plate3_T0_0_B2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_12.tif', 0.62], ['PID20190102_SB11-15-Plate3_T0_0_D2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_6.tif', 0.95], ['PID20190102_SB11-15-Plate3_T0_0_F1_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_5.tif', 0.81], ['PID20190102_SB11-15-Plate3_T0_0_G1_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_9.tif', 0.81], ['PID20190102_SB11-15-Plate3_T0_0_H2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_11.tif', 0.8], ['PID20190102_SB11-15-Plate3_T0_0_H2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_15.tif', 0.88], ['PID20190102_SB11-15-Plate3_T0_0_H2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_19.tif', 0.83], ['PID20190102_SB11-15-Plate3_T0_0_H2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_9.tif', 0.94], ['PID20190131_SB21-25-plate6_T1_24_A1_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_7.tif', 0.63], ['PID20190131_SB21-25-plate6_T1_24_A2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_5.tif', 0.85], ['PID20190131_SB21-25-plate6_T1_24_A3_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_6.tif', 0.78], ['PID20190131_SB21-25-plate6_T1_24_A3_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_7.tif', 0.77], ['PID20190131_SB21-25-plate6_T1_24_A5_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_5.tif', 0.82], ['PID20190131_SB21-25-plate6_T1_24_B1_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_1.tif', 0.43], ['PID20190131_SB21-25-plate6_T1_24_B2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_7.tif', 0.7], ['PID20190131_SB21-25-plate6_T1_24_B3_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_3.tif', 0.4], ['PID20190131_SB21-25-plate6_T1_24_C4_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_5.tif', 0.3], ['PID20190131_SB21-25-plate6_T1_24_C5_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_27.tif', 0.49], ['PID20190206_SB26-30plate1_T0_0_D2_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_2.tif', 0.69], ['PID20190206_SB26-30plate1_T0_0_D4_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_3.tif', 0.67], ['PID20190206_SB26-30plate1_T0_0_D5_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_1.tif', 0.63], ['PID20190206_SB26-30plate1_T0_0_E3_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_2.tif', 0.57], ['PID20190206_SB26-30plate1_T0_0_E7_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_4.tif', 0.91], ['PID20190206_SB26-30plate1_T0_0_E8_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_4.tif', 0.76], ['PID20190206_SB26-30plate1_T0_0_F11_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_1.tif', 0.41], ['PID20190206_SB26-30plate1_T0_0_F6_0_RFP-DFTrCy5_BGpbs_MN_ALIGNED_2.tif', 0. ...

# %%
img_eccentricity_list_class1 = [fn[1] for fn in img_eccentricity_list]
print("the values of the eccentricity of class 1: ", img_eccentricity_list_class1)
# Out:
# the values of the eccentricity of class 1:  [0.66, 0.72, 0.54, 0.6, 0.71, 0.84, 0.93, 0.75, 0.79, 0.88, 0.7, 0.74, 0.79, 0.81, 0.79, 0.86, 0.7, 0.62, 0.59, 0.74, 0.93, 0.78, 0.62, 0.95, 0.81, 0.81, 0.8, 0.88, 0.83, 0.94, 0.63, 0.85, 0.78, 0.77, 0.82, 0.43, 0.7, 0.4, 0.3, 0.49, 0.69, 0.67, 0.63, 0.57, 0.91, 0.76, 0.41, 0.57, 0.41, 0.72, 0.28, 0.73, 0.78, 0.78, 0.61, 0.7, 0.63, 0.49, 0.87, 0.66, 0.83, 0.87, 0.86, 0.71, 0.85, 0.71, 0.88, 0.68, 0.52, 0.35, 0.95, 0.67, 0.96, 0.84, 0.65, 0.75, 0.67, 0.72, 0.99, 0.78, 0.29, 0.68, 0.69, 0.51, 0.46, 0.85, 0.39, 0.2, 0.87, 0.82, 0.42, 0.53, 0.7, 0.99, 0.69, 0.69, 0.63, 0.67, 0.99, 0.59, 0.83, 0.97, 0.89, 0.34, 0.48]

# %%
plt.title("134 crops each class")
plt.hist(img_eccentricity_list_class1, bins=30, range=(np.min(img_eccentricity_list_class1),
                                                          np.max(img_eccentricity_list_class1)),
             label='Class1', alpha=0.7)
plt.legend(loc='upper right')
plt.show()
